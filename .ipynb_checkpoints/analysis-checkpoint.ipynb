# %% [markdown]
# # Analysis of Config Results

# %%
import os
import json
from scoring_pipeline import ScoringPipeline
import pandas as pd
from tqdm import tqdm

def load_config(config_file):
    with open(config_file, 'r') as f:
        return json.load(f)

def get_bit_size(config):
    if config and 'num_bits' in config[0]:
        return config[0]['num_bits']
    return None

def get_layer_type(config):
    if config and 'layer_type' in config[0]:
        return config[0]['layer_type']
    return None

def get_quantized_parts(config):
    parts = {
        'VIT': {'FIRST': 0, 'MIDDLE': 0, 'LAST': 0},
        'QFORMER': {'FIRST': 0, 'MIDDLE': 0, 'LAST': 0},
        'LLM': {'FIRST': 0, 'MIDDLE': 0, 'LAST': 0}
    }
    for item in config:
        if 'model_part' in item and 'layer_group' in item:
            if item['layer_group'] == 'ALL':
                parts[item['model_part']] = {'FIRST': 1, 'MIDDLE': 1, 'LAST': 1}
            else:
                parts[item['model_part']][item['layer_group']] = 1
    return parts

results = []
scorer = ScoringPipeline()

# %% [markdown]
# ## Run Scoring Pipeline

# %%
# Get list of files and use tqdm for progress bar
result_files = [f for f in os.listdir('./results') if f.endswith('.json')]
for filename in tqdm(result_files, desc="Processing files"):
    config_number = filename.split('.')[0]
    
    # Load and process config
    config_file = os.path.join('./configs', filename)
    config = load_config(config_file)
    bit_size = get_bit_size(config)
    layer_type = get_layer_type(config)
    quantized_parts = get_quantized_parts(config)

    # Load and process results
    result_file = os.path.join('./results', filename)
    loaded_results = scorer.load_results(result_file)
    scores = scorer.compute_scores(loaded_results, task='image_captioning')

    # Compile row data
    row = {
        'config': config_number,
        'bit_size': bit_size,
        'type': layer_type,
        'VIT_FIRST': quantized_parts['VIT']['FIRST'],
        'VIT_MIDDLE': quantized_parts['VIT']['MIDDLE'],
        'VIT_LAST': quantized_parts['VIT']['LAST'],
        'QFORMER_FIRST': quantized_parts['QFORMER']['FIRST'],
        'QFORMER_MIDDLE': quantized_parts['QFORMER']['MIDDLE'],
        'QFORMER_LAST': quantized_parts['QFORMER']['LAST'],
        'LLM_FIRST': quantized_parts['LLM']['FIRST'],
        'LLM_MIDDLE': quantized_parts['LLM']['MIDDLE'],
        'LLM_LAST': quantized_parts['LLM']['LAST'],
    }

    # Add metrics
    for metric, score in scores.items():
        if not metric.endswith('_per_caption'):
            row[metric] = score

    results.append(row)

# Create DataFrame and save to CSV
df = pd.DataFrame(results)
df.to_csv('quantization_results.csv', index=False)
print("Results saved to quantization_results.csv")
# Out:
# Processing files:   0%|                                                                            | 0/1500 [00:00<?, ?it/s]PTBTokenizer tokenized 61766 tokens at 862254.84 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 223203.49 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   0%|                                                                    | 1/1500 [00:01<29:39,  1.19s/it]PTBTokenizer tokenized 61766 tokens at 865772.89 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 8482 tokens at 208385.64 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   0%|                                                                    | 2/1500 [00:02<26:36,  1.07s/it]PTBTokenizer tokenized 61766 tokens at 894441.29 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 8055 tokens at 194601.52 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   0%|▏                                                                   | 3/1500 [00:03<25:15,  1.01s/it]PTBTokenizer tokenized 61766 tokens at 914270.87 tokens per second.
# Tokenizing...
# Aug 02, 2024 2:45:00 PM edu.stanford.nlp.process.PTBLexer next
# WARNING: Untokenizable: � (U+FFFD, decimal: 65533)
# PTBTokenizer tokenized 12171 tokens at 176097.13 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   0%|▏                                                                   | 4/1500 [00:04<25:35,  1.03s/it]PTBTokenizer tokenized 61766 tokens at 893492.10 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 222064.71 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   0%|▏                                                                   | 5/1500 [00:05<25:26,  1.02s/it]PTBTokenizer tokenized 61766 tokens at 915493.36 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9152 tokens at 224757.88 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   0%|▎                                                                   | 6/1500 [00:06<25:01,  1.00s/it]PTBTokenizer tokenized 61766 tokens at 913761.94 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 8714 tokens at 220913.94 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   0%|▎                                                                   | 7/1500 [00:06<23:01,  1.08it/s]PTBTokenizer tokenized 61766 tokens at 914845.84 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9239 tokens at 226368.32 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   1%|▎                                                                   | 8/1500 [00:07<23:07,  1.08it/s]PTBTokenizer tokenized 61766 tokens at 885889.98 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 218179.84 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   1%|▍                                                                   | 9/1500 [00:08<23:37,  1.05it/s]PTBTokenizer tokenized 61766 tokens at 921685.50 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 6926 tokens at 176065.03 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   1%|▍                                                                  | 10/1500 [00:09<23:04,  1.08it/s]PTBTokenizer tokenized 61766 tokens at 916014.66 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 999 tokens at 31627.52 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   1%|▍                                                                  | 11/1500 [00:10<21:26,  1.16it/s]PTBTokenizer tokenized 61766 tokens at 915135.42 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9284 tokens at 228921.82 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   1%|▌                                                                  | 12/1500 [00:11<22:22,  1.11it/s]PTBTokenizer tokenized 61766 tokens at 914721.36 tokens per second.
# Tokenizing...
# Aug 02, 2024 2:45:08 PM edu.stanford.nlp.process.PTBLexer next
# WARNING: Untokenizable: � (U+FFFD, decimal: 65533)
# PTBTokenizer tokenized 12171 tokens at 199607.42 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   1%|▌                                                                  | 13/1500 [00:12<23:04,  1.07it/s]PTBTokenizer tokenized 61766 tokens at 919184.70 tokens per second.
# Tokenizing...
# Aug 02, 2024 2:45:09 PM edu.stanford.nlp.process.PTBLexer next
# WARNING: Untokenizable: � (U+FFFD, decimal: 65533)
# PTBTokenizer tokenized 12023 tokens at 198291.13 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   1%|▋                                                                  | 14/1500 [00:13<23:56,  1.03it/s]PTBTokenizer tokenized 61766 tokens at 873695.31 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 218873.43 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   1%|▋                                                                  | 15/1500 [00:14<24:05,  1.03it/s]PTBTokenizer tokenized 61766 tokens at 916871.14 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 8086 tokens at 205290.64 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   1%|▋                                                                  | 16/1500 [00:15<23:51,  1.04it/s]PTBTokenizer tokenized 61766 tokens at 855978.75 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 999 tokens at 28585.58 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   1%|▊                                                                  | 17/1500 [00:16<22:07,  1.12it/s]PTBTokenizer tokenized 61766 tokens at 879474.56 tokens per second.
# Tokenizing...
# Aug 02, 2024 2:45:13 PM edu.stanford.nlp.process.PTBLexer next
# WARNING: Untokenizable: � (U+FFFD, decimal: 65533)
# PTBTokenizer tokenized 9838 tokens at 157721.10 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   1%|▊                                                                  | 18/1500 [00:17<22:15,  1.11it/s]PTBTokenizer tokenized 61766 tokens at 889704.08 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 999 tokens at 31465.40 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   1%|▊                                                                  | 19/1500 [00:17<21:05,  1.17it/s]PTBTokenizer tokenized 61766 tokens at 900278.36 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 229044.29 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   1%|▉                                                                  | 20/1500 [00:18<21:46,  1.13it/s]PTBTokenizer tokenized 61766 tokens at 896095.16 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 2009 tokens at 56234.25 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   1%|▉                                                                  | 21/1500 [00:19<20:48,  1.18it/s]PTBTokenizer tokenized 61766 tokens at 858900.33 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9168 tokens at 225765.31 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   1%|▉                                                                  | 22/1500 [00:20<21:34,  1.14it/s]PTBTokenizer tokenized 61766 tokens at 904792.07 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9412 tokens at 222965.50 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   2%|█                                                                  | 23/1500 [00:21<22:26,  1.10it/s]PTBTokenizer tokenized 61766 tokens at 879098.29 tokens per second.
# Tokenizing...
# Aug 02, 2024 2:45:18 PM edu.stanford.nlp.process.PTBLexer next
# WARNING: Untokenizable: � (U+FFFD, decimal: 65533)
# PTBTokenizer tokenized 13306 tokens at 200049.19 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   2%|█                                                                  | 24/1500 [00:22<22:43,  1.08it/s]PTBTokenizer tokenized 61766 tokens at 894176.90 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 999 tokens at 30349.31 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   2%|█                                                                  | 25/1500 [00:23<21:24,  1.15it/s]PTBTokenizer tokenized 61766 tokens at 900008.82 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 1925 tokens at 58024.43 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   2%|█▏                                                                 | 26/1500 [00:23<20:25,  1.20it/s]PTBTokenizer tokenized 61766 tokens at 916341.68 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9229 tokens at 224978.76 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   2%|█▏                                                                 | 27/1500 [00:24<21:29,  1.14it/s]PTBTokenizer tokenized 61766 tokens at 894779.89 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 999 tokens at 30502.66 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   2%|█▎                                                                 | 28/1500 [00:25<20:23,  1.20it/s]PTBTokenizer tokenized 61766 tokens at 908957.29 tokens per second.
# Tokenizing...
# Aug 02, 2024 2:45:22 PM edu.stanford.nlp.process.PTBLexer next
# WARNING: Untokenizable: � (U+FFFD, decimal: 65533)
# PTBTokenizer tokenized 17540 tokens at 287297.09 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   2%|█▎                                                                 | 29/1500 [00:26<22:39,  1.08it/s]PTBTokenizer tokenized 61766 tokens at 911602.68 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 7765 tokens at 195391.39 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   2%|█▎                                                                 | 30/1500 [00:27<22:40,  1.08it/s]PTBTokenizer tokenized 61766 tokens at 911573.14 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9233 tokens at 227969.65 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   2%|█▍                                                                 | 31/1500 [00:28<22:53,  1.07it/s]PTBTokenizer tokenized 61766 tokens at 831956.27 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9116 tokens at 219392.05 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   2%|█▍                                                                 | 32/1500 [00:29<23:09,  1.06it/s]PTBTokenizer tokenized 61766 tokens at 878872.35 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9235 tokens at 212735.18 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   2%|█▍                                                                 | 33/1500 [00:30<23:13,  1.05it/s]PTBTokenizer tokenized 61766 tokens at 861593.07 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 7062 tokens at 185592.46 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   2%|█▌                                                                 | 34/1500 [00:31<22:49,  1.07it/s]PTBTokenizer tokenized 61766 tokens at 914835.58 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9289 tokens at 227378.65 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   2%|█▌                                                                 | 35/1500 [00:32<22:56,  1.06it/s]PTBTokenizer tokenized 61766 tokens at 919660.04 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9244 tokens at 225890.92 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   2%|█▌                                                                 | 36/1500 [00:33<22:59,  1.06it/s]PTBTokenizer tokenized 61766 tokens at 900758.69 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9238 tokens at 225770.71 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   2%|█▋                                                                 | 37/1500 [00:34<23:19,  1.05it/s]PTBTokenizer tokenized 61766 tokens at 901080.81 tokens per second.
# Tokenizing...
# Aug 02, 2024 2:45:31 PM edu.stanford.nlp.process.PTBLexer next
# WARNING: Untokenizable: � (U+FFFD, decimal: 65533)
# PTBTokenizer tokenized 17504 tokens at 260386.04 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   3%|█▋                                                                 | 38/1500 [00:35<24:42,  1.01s/it]PTBTokenizer tokenized 61766 tokens at 916060.92 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 226275.85 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   3%|█▋                                                                 | 39/1500 [00:36<24:11,  1.01it/s]PTBTokenizer tokenized 61766 tokens at 906515.78 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 11034 tokens at 256632.93 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   3%|█▊                                                                 | 40/1500 [00:37<24:07,  1.01it/s]PTBTokenizer tokenized 61766 tokens at 901011.84 tokens per second.
# Tokenizing...
# Aug 02, 2024 2:45:34 PM edu.stanford.nlp.process.PTBLexer next
# WARNING: Untokenizable: � (U+FFFD, decimal: 65533)
# PTBTokenizer tokenized 12414 tokens at 198187.25 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   3%|█▊                                                                 | 41/1500 [00:38<24:17,  1.00it/s]PTBTokenizer tokenized 61766 tokens at 901143.52 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 8135 tokens at 205929.75 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   3%|█▉                                                                 | 42/1500 [00:39<23:34,  1.03it/s]PTBTokenizer tokenized 61766 tokens at 910263.88 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9321 tokens at 222461.72 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   3%|█▉                                                                 | 43/1500 [00:40<23:13,  1.05it/s]PTBTokenizer tokenized 61766 tokens at 862766.95 tokens per second.
# Tokenizing...
# Aug 02, 2024 2:45:37 PM edu.stanford.nlp.process.PTBLexer next
# WARNING: Untokenizable: � (U+FFFD, decimal: 65533)
# PTBTokenizer tokenized 12054 tokens at 182398.82 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   3%|█▉                                                                 | 44/1500 [00:41<23:44,  1.02it/s]PTBTokenizer tokenized 61766 tokens at 905317.13 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 227157.15 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   3%|██                                                                 | 45/1500 [00:42<23:28,  1.03it/s]PTBTokenizer tokenized 61766 tokens at 870062.66 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9241 tokens at 224840.38 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   3%|██                                                                 | 46/1500 [00:43<23:16,  1.04it/s]PTBTokenizer tokenized 61766 tokens at 919663.88 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 222346.96 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   3%|██                                                                 | 47/1500 [00:44<23:11,  1.04it/s]PTBTokenizer tokenized 61766 tokens at 917080.15 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 999 tokens at 30902.55 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   3%|██▏                                                                | 48/1500 [00:44<21:43,  1.11it/s]PTBTokenizer tokenized 61766 tokens at 914667.42 tokens per second.
# Tokenizing...
# Aug 02, 2024 2:45:42 PM edu.stanford.nlp.process.PTBLexer next
# WARNING: Untokenizable: � (U+FFFD, decimal: 65533)
# PTBTokenizer tokenized 10292 tokens at 150251.87 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   3%|██▏                                                                | 49/1500 [00:45<21:34,  1.12it/s]PTBTokenizer tokenized 61766 tokens at 909859.59 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9263 tokens at 227239.79 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   3%|██▏                                                                | 50/1500 [00:46<21:54,  1.10it/s]PTBTokenizer tokenized 61766 tokens at 884287.20 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 1242 tokens at 37072.50 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   3%|██▎                                                                | 51/1500 [00:47<20:35,  1.17it/s]PTBTokenizer tokenized 61766 tokens at 902760.04 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 225990.76 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   3%|██▎                                                                | 52/1500 [00:48<21:25,  1.13it/s]PTBTokenizer tokenized 61766 tokens at 912637.05 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 214591.24 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   4%|██▎                                                                | 53/1500 [00:49<21:51,  1.10it/s]PTBTokenizer tokenized 61766 tokens at 906500.97 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 216384.19 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   4%|██▍                                                                | 54/1500 [00:50<22:17,  1.08it/s]PTBTokenizer tokenized 61766 tokens at 872056.96 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 227231.67 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   4%|██▍                                                                | 55/1500 [00:51<22:41,  1.06it/s]PTBTokenizer tokenized 61766 tokens at 922146.06 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9229 tokens at 219963.50 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   4%|██▌                                                                | 56/1500 [00:52<22:46,  1.06it/s]PTBTokenizer tokenized 61766 tokens at 898549.52 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9234 tokens at 224138.60 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   4%|██▌                                                                | 57/1500 [00:53<22:44,  1.06it/s]PTBTokenizer tokenized 61766 tokens at 913331.10 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 224649.25 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   4%|██▌                                                                | 58/1500 [00:54<22:44,  1.06it/s]PTBTokenizer tokenized 61766 tokens at 909588.35 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 228829.40 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   4%|██▋                                                                | 59/1500 [00:55<23:04,  1.04it/s]PTBTokenizer tokenized 61766 tokens at 920766.80 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 11791 tokens at 272871.58 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   4%|██▋                                                                | 60/1500 [00:56<23:19,  1.03it/s]PTBTokenizer tokenized 61766 tokens at 913480.96 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9243 tokens at 225948.11 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   4%|██▋                                                                | 61/1500 [00:57<23:05,  1.04it/s]PTBTokenizer tokenized 61766 tokens at 914029.18 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 4895 tokens at 134923.18 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   4%|██▊                                                                | 62/1500 [00:57<21:49,  1.10it/s]PTBTokenizer tokenized 61766 tokens at 915306.90 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9202 tokens at 224817.24 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   4%|██▊                                                                | 63/1500 [00:58<22:05,  1.08it/s]PTBTokenizer tokenized 61766 tokens at 911539.29 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 7104 tokens at 177614.56 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   4%|██▊                                                                | 64/1500 [00:59<21:47,  1.10it/s]PTBTokenizer tokenized 61766 tokens at 910792.08 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 227155.17 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   4%|██▉                                                                | 65/1500 [01:00<22:16,  1.07it/s]PTBTokenizer tokenized 61766 tokens at 920318.36 tokens per second.
# Tokenizing...
# Aug 02, 2024 2:45:58 PM edu.stanford.nlp.process.PTBLexer next
# WARNING: Untokenizable: � (U+FFFD, decimal: 65533)
# PTBTokenizer tokenized 17821 tokens at 287252.20 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   4%|██▉                                                                | 66/1500 [01:01<23:35,  1.01it/s]PTBTokenizer tokenized 61766 tokens at 911463.66 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 1215 tokens at 38156.16 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   4%|██▉                                                                | 67/1500 [01:02<21:35,  1.11it/s]PTBTokenizer tokenized 61766 tokens at 914511.30 tokens per second.
# Tokenizing...
# Aug 02, 2024 2:45:59 PM edu.stanford.nlp.process.PTBLexer next
# WARNING: Untokenizable: � (U+FFFD, decimal: 65533)
# PTBTokenizer tokenized 13413 tokens at 195708.32 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   5%|███                                                                | 68/1500 [01:03<21:53,  1.09it/s]PTBTokenizer tokenized 61766 tokens at 900176.23 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9239 tokens at 229681.36 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   5%|███                                                                | 69/1500 [01:04<22:21,  1.07it/s]PTBTokenizer tokenized 61766 tokens at 904064.31 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9203 tokens at 221279.80 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   5%|███▏                                                               | 70/1500 [01:05<22:24,  1.06it/s]PTBTokenizer tokenized 61766 tokens at 835765.57 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9161 tokens at 226884.14 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   5%|███▏                                                               | 71/1500 [01:06<22:24,  1.06it/s]PTBTokenizer tokenized 61766 tokens at 897360.72 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 999 tokens at 31065.94 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   5%|███▏                                                               | 72/1500 [01:07<21:07,  1.13it/s]PTBTokenizer tokenized 61766 tokens at 922701.86 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9231 tokens at 230833.17 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   5%|███▎                                                               | 73/1500 [01:08<21:29,  1.11it/s]PTBTokenizer tokenized 61766 tokens at 905476.38 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 1999 tokens at 57489.42 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   5%|███▎                                                               | 74/1500 [01:08<20:21,  1.17it/s]PTBTokenizer tokenized 61766 tokens at 920913.57 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 226752.50 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   5%|███▎                                                               | 75/1500 [01:09<20:57,  1.13it/s]PTBTokenizer tokenized 61766 tokens at 889497.34 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9291 tokens at 228761.45 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   5%|███▍                                                               | 76/1500 [01:10<21:31,  1.10it/s]PTBTokenizer tokenized 61766 tokens at 921712.61 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 1895 tokens at 45289.66 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   5%|███▍                                                               | 77/1500 [01:11<20:19,  1.17it/s]PTBTokenizer tokenized 61766 tokens at 906070.00 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9088 tokens at 224315.50 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   5%|███▍                                                               | 78/1500 [01:12<20:49,  1.14it/s]PTBTokenizer tokenized 61766 tokens at 879397.03 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 999 tokens at 30785.88 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   5%|███▌                                                               | 79/1500 [01:13<19:42,  1.20it/s]PTBTokenizer tokenized 61766 tokens at 901861.81 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 227389.39 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   5%|███▌                                                               | 80/1500 [01:14<20:43,  1.14it/s]PTBTokenizer tokenized 61766 tokens at 896473.01 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 226646.12 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   5%|███▌                                                               | 81/1500 [01:15<21:14,  1.11it/s]PTBTokenizer tokenized 61766 tokens at 877240.90 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 223233.13 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   5%|███▋                                                               | 82/1500 [01:15<21:38,  1.09it/s]PTBTokenizer tokenized 61766 tokens at 898102.61 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 229803.69 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   6%|███▋                                                               | 83/1500 [01:16<22:03,  1.07it/s]PTBTokenizer tokenized 61766 tokens at 909487.94 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 214057.65 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   6%|███▊                                                               | 84/1500 [01:17<22:08,  1.07it/s]PTBTokenizer tokenized 61766 tokens at 908182.05 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 999 tokens at 31189.84 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   6%|███▊                                                               | 85/1500 [01:18<20:34,  1.15it/s]PTBTokenizer tokenized 61766 tokens at 890174.06 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 2047 tokens at 54901.70 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   6%|███▊                                                               | 86/1500 [01:19<19:53,  1.19it/s]PTBTokenizer tokenized 61766 tokens at 907927.22 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9151 tokens at 222373.57 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   6%|███▉                                                               | 87/1500 [01:20<20:55,  1.13it/s]PTBTokenizer tokenized 61766 tokens at 916205.04 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 225391.64 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   6%|███▉                                                               | 88/1500 [01:21<21:20,  1.10it/s]PTBTokenizer tokenized 61766 tokens at 906085.03 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 226574.63 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   6%|███▉                                                               | 89/1500 [01:22<21:37,  1.09it/s]PTBTokenizer tokenized 61766 tokens at 893912.71 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9227 tokens at 218633.47 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   6%|████                                                               | 90/1500 [01:23<22:10,  1.06it/s]PTBTokenizer tokenized 61766 tokens at 919227.43 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 226009.14 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   6%|████                                                               | 91/1500 [01:24<22:12,  1.06it/s]PTBTokenizer tokenized 61766 tokens at 905520.00 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9204 tokens at 229248.04 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   6%|████                                                               | 92/1500 [01:25<22:08,  1.06it/s]PTBTokenizer tokenized 61766 tokens at 850879.26 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9214 tokens at 225545.78 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   6%|████▏                                                              | 93/1500 [01:26<22:12,  1.06it/s]PTBTokenizer tokenized 61766 tokens at 898582.21 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 224628.91 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   6%|████▏                                                              | 94/1500 [01:27<22:24,  1.05it/s]PTBTokenizer tokenized 61766 tokens at 909884.15 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9159 tokens at 221826.80 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   6%|████▏                                                              | 95/1500 [01:28<22:17,  1.05it/s]PTBTokenizer tokenized 61766 tokens at 908584.31 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 999 tokens at 30908.95 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   6%|████▎                                                              | 96/1500 [01:28<20:52,  1.12it/s]PTBTokenizer tokenized 61766 tokens at 899807.55 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 229294.36 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   6%|████▎                                                              | 97/1500 [01:29<21:10,  1.10it/s]PTBTokenizer tokenized 61766 tokens at 894383.85 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 8089 tokens at 186009.98 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   7%|████▍                                                              | 98/1500 [01:30<21:22,  1.09it/s]PTBTokenizer tokenized 61766 tokens at 911972.14 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 225909.75 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   7%|████▍                                                              | 99/1500 [01:31<21:38,  1.08it/s]PTBTokenizer tokenized 61766 tokens at 904206.69 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9238 tokens at 225490.58 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   7%|████▍                                                             | 100/1500 [01:32<21:45,  1.07it/s]PTBTokenizer tokenized 61766 tokens at 910260.59 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 224526.66 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   7%|████▍                                                             | 101/1500 [01:33<22:12,  1.05it/s]PTBTokenizer tokenized 61766 tokens at 918183.24 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 12273 tokens at 278764.86 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   7%|████▍                                                             | 102/1500 [01:34<22:30,  1.04it/s]PTBTokenizer tokenized 61766 tokens at 905796.98 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 8471 tokens at 213754.39 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   7%|████▌                                                             | 103/1500 [01:35<22:11,  1.05it/s]PTBTokenizer tokenized 61766 tokens at 908903.38 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9331 tokens at 229912.47 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   7%|████▌                                                             | 104/1500 [01:36<22:12,  1.05it/s]PTBTokenizer tokenized 61766 tokens at 898087.51 tokens per second.
# Tokenizing...
# Aug 02, 2024 2:46:33 PM edu.stanford.nlp.process.PTBLexer next
# WARNING: Untokenizable: � (U+FFFD, decimal: 65533)
# PTBTokenizer tokenized 17504 tokens at 290640.05 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   7%|████▌                                                             | 105/1500 [01:37<23:40,  1.02s/it]PTBTokenizer tokenized 61766 tokens at 915630.53 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 6805 tokens at 174709.53 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   7%|████▋                                                             | 106/1500 [01:38<22:43,  1.02it/s]PTBTokenizer tokenized 61766 tokens at 922335.43 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9169 tokens at 224987.16 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   7%|████▋                                                             | 107/1500 [01:39<22:26,  1.03it/s]PTBTokenizer tokenized 61766 tokens at 905489.83 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 228213.48 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   7%|████▊                                                             | 108/1500 [01:40<22:22,  1.04it/s]PTBTokenizer tokenized 61766 tokens at 905852.03 tokens per second.
# Tokenizing...
# Aug 02, 2024 2:46:37 PM edu.stanford.nlp.process.PTBLexer next
# WARNING: Untokenizable: � (U+FFFD, decimal: 65533)
# PTBTokenizer tokenized 17541 tokens at 285226.99 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   7%|████▊                                                             | 109/1500 [01:41<23:23,  1.01s/it]PTBTokenizer tokenized 61766 tokens at 906149.69 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 229783.35 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   7%|████▊                                                             | 110/1500 [01:42<23:01,  1.01it/s]PTBTokenizer tokenized 61766 tokens at 906426.03 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 228234.48 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   7%|████▉                                                             | 111/1500 [01:43<22:53,  1.01it/s]PTBTokenizer tokenized 61766 tokens at 910014.11 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 1999 tokens at 53837.08 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   7%|████▉                                                             | 112/1500 [01:44<21:42,  1.07it/s]PTBTokenizer tokenized 61766 tokens at 911556.32 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9235 tokens at 226439.79 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   8%|████▉                                                             | 113/1500 [01:45<21:45,  1.06it/s]PTBTokenizer tokenized 61766 tokens at 894998.90 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 226282.88 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   8%|█████                                                             | 114/1500 [01:46<21:56,  1.05it/s]PTBTokenizer tokenized 61766 tokens at 904664.20 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9204 tokens at 201922.22 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   8%|█████                                                             | 115/1500 [01:47<22:08,  1.04it/s]PTBTokenizer tokenized 61766 tokens at 902953.65 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9229 tokens at 225969.09 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   8%|█████                                                             | 116/1500 [01:48<22:09,  1.04it/s]PTBTokenizer tokenized 61766 tokens at 901825.03 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9224 tokens at 216804.05 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   8%|█████▏                                                            | 117/1500 [01:49<22:08,  1.04it/s]PTBTokenizer tokenized 61766 tokens at 900762.13 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9284 tokens at 224299.32 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   8%|█████▏                                                            | 118/1500 [01:50<22:19,  1.03it/s]PTBTokenizer tokenized 61766 tokens at 899611.05 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9224 tokens at 224823.32 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   8%|█████▏                                                            | 119/1500 [01:51<22:11,  1.04it/s]PTBTokenizer tokenized 61766 tokens at 924244.48 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 999 tokens at 31224.46 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   8%|█████▎                                                            | 120/1500 [01:51<20:29,  1.12it/s]PTBTokenizer tokenized 61766 tokens at 908823.84 tokens per second.
# Tokenizing...
# Aug 02, 2024 2:46:49 PM edu.stanford.nlp.process.PTBLexer next
# WARNING: Untokenizable: � (U+FFFD, decimal: 65533)
# PTBTokenizer tokenized 11173 tokens at 145674.99 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   8%|█████▎                                                            | 121/1500 [01:52<20:53,  1.10it/s]PTBTokenizer tokenized 61766 tokens at 912640.71 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 220012.23 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   8%|█████▎                                                            | 122/1500 [01:53<21:25,  1.07it/s]PTBTokenizer tokenized 61766 tokens at 914528.29 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 7733 tokens at 199639.87 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   8%|█████▍                                                            | 123/1500 [01:54<21:21,  1.07it/s]PTBTokenizer tokenized 61766 tokens at 907637.56 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 8050 tokens at 198398.66 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   8%|█████▍                                                            | 124/1500 [01:55<21:20,  1.07it/s]PTBTokenizer tokenized 61766 tokens at 909397.41 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 999 tokens at 31586.96 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   8%|█████▌                                                            | 125/1500 [01:56<19:50,  1.16it/s]PTBTokenizer tokenized 61766 tokens at 922499.42 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 228639.95 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   8%|█████▌                                                            | 126/1500 [01:57<20:30,  1.12it/s]PTBTokenizer tokenized 61766 tokens at 917133.96 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 11791 tokens at 267867.28 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   8%|█████▌                                                            | 127/1500 [01:58<21:13,  1.08it/s]PTBTokenizer tokenized 61766 tokens at 902900.89 tokens per second.
# Tokenizing...
# Aug 02, 2024 2:46:55 PM edu.stanford.nlp.process.PTBLexer next
# WARNING: Untokenizable: � (U+FFFD, decimal: 65533)
# PTBTokenizer tokenized 12023 tokens at 199842.72 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   9%|█████▋                                                            | 128/1500 [01:59<21:42,  1.05it/s]PTBTokenizer tokenized 61766 tokens at 910772.40 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 221936.64 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   9%|█████▋                                                            | 129/1500 [02:00<22:00,  1.04it/s]PTBTokenizer tokenized 61766 tokens at 874220.11 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 1999 tokens at 53875.03 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   9%|█████▋                                                            | 130/1500 [02:01<20:37,  1.11it/s]PTBTokenizer tokenized 61766 tokens at 912266.68 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 222472.18 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   9%|█████▊                                                            | 131/1500 [02:01<20:52,  1.09it/s]PTBTokenizer tokenized 61766 tokens at 911905.33 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9261 tokens at 228522.98 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   9%|█████▊                                                            | 132/1500 [02:02<21:09,  1.08it/s]PTBTokenizer tokenized 61766 tokens at 860530.96 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 226946.73 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:   9%|█████▊                                                            | 133/1500 [02:03<21:30,  1.06it/s]PTBTokenizer tokenized 61766 tokens at 917909.62 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 225469.06 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# ...
# Tokenizing...
# PTBTokenizer tokenized 8135 tokens at 203665.41 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  97%|███████████████████████████████████████████████████████████████  | 1455/1500 [22:35<00:40,  1.12it/s]PTBTokenizer tokenized 61766 tokens at 895969.64 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 18819 tokens at 404055.10 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  97%|███████████████████████████████████████████████████████████████  | 1456/1500 [22:36<00:40,  1.08it/s]PTBTokenizer tokenized 61766 tokens at 899860.09 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 214958.68 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  97%|███████████████████████████████████████████████████████████████▏ | 1457/1500 [22:37<00:40,  1.07it/s]PTBTokenizer tokenized 61766 tokens at 906021.90 tokens per second.
# Tokenizing...
# Aug 02, 2024 3:07:35 PM edu.stanford.nlp.process.PTBLexer next
# WARNING: Untokenizable: � (U+FFFD, decimal: 65533)
# PTBTokenizer tokenized 17504 tokens at 277021.61 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  97%|███████████████████████████████████████████████████████████████▏ | 1458/1500 [22:39<00:41,  1.00it/s]PTBTokenizer tokenized 61766 tokens at 903907.08 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 8523 tokens at 212638.55 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  97%|███████████████████████████████████████████████████████████████▏ | 1459/1500 [22:39<00:40,  1.02it/s]PTBTokenizer tokenized 61766 tokens at 895491.56 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 8536 tokens at 210423.12 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  97%|███████████████████████████████████████████████████████████████▎ | 1460/1500 [22:40<00:38,  1.03it/s]PTBTokenizer tokenized 61766 tokens at 900799.10 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9204 tokens at 226692.17 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  97%|███████████████████████████████████████████████████████████████▎ | 1461/1500 [22:41<00:37,  1.04it/s]PTBTokenizer tokenized 61766 tokens at 899846.75 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 999 tokens at 29138.46 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  97%|███████████████████████████████████████████████████████████████▎ | 1462/1500 [22:42<00:34,  1.12it/s]PTBTokenizer tokenized 61766 tokens at 878494.79 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 999 tokens at 31130.68 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  98%|███████████████████████████████████████████████████████████████▍ | 1463/1500 [22:43<00:31,  1.17it/s]PTBTokenizer tokenized 61766 tokens at 893784.37 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 11648 tokens at 264221.79 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  98%|███████████████████████████████████████████████████████████████▍ | 1464/1500 [22:44<00:32,  1.11it/s]PTBTokenizer tokenized 61766 tokens at 897892.20 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 224024.11 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  98%|███████████████████████████████████████████████████████████████▍ | 1465/1500 [22:45<00:32,  1.09it/s]PTBTokenizer tokenized 61766 tokens at 899845.80 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 8523 tokens at 204803.43 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  98%|███████████████████████████████████████████████████████████████▌ | 1466/1500 [22:46<00:31,  1.08it/s]PTBTokenizer tokenized 61766 tokens at 912135.30 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 223811.94 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  98%|███████████████████████████████████████████████████████████████▌ | 1467/1500 [22:47<00:31,  1.06it/s]PTBTokenizer tokenized 61766 tokens at 903013.77 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9134 tokens at 223317.40 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  98%|███████████████████████████████████████████████████████████████▌ | 1468/1500 [22:48<00:30,  1.06it/s]PTBTokenizer tokenized 61766 tokens at 872818.53 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 7767 tokens at 198312.52 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  98%|███████████████████████████████████████████████████████████████▋ | 1469/1500 [22:49<00:28,  1.07it/s]PTBTokenizer tokenized 61766 tokens at 898865.00 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 999 tokens at 31071.88 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  98%|███████████████████████████████████████████████████████████████▋ | 1470/1500 [22:49<00:26,  1.14it/s]PTBTokenizer tokenized 61766 tokens at 907471.27 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 4953 tokens at 137132.08 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  98%|███████████████████████████████████████████████████████████████▋ | 1471/1500 [22:50<00:24,  1.17it/s]PTBTokenizer tokenized 61766 tokens at 900682.05 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 7266 tokens at 190136.17 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  98%|███████████████████████████████████████████████████████████████▊ | 1472/1500 [22:51<00:24,  1.15it/s]PTBTokenizer tokenized 61766 tokens at 847851.73 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9203 tokens at 222358.78 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  98%|███████████████████████████████████████████████████████████████▊ | 1473/1500 [22:52<00:24,  1.11it/s]PTBTokenizer tokenized 61766 tokens at 898249.36 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 7776 tokens at 196917.73 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  98%|███████████████████████████████████████████████████████████████▊ | 1474/1500 [22:53<00:23,  1.09it/s]PTBTokenizer tokenized 61766 tokens at 863654.66 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 7755 tokens at 197233.66 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  98%|███████████████████████████████████████████████████████████████▉ | 1475/1500 [22:54<00:22,  1.09it/s]PTBTokenizer tokenized 61766 tokens at 901234.35 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9151 tokens at 218776.16 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  98%|███████████████████████████████████████████████████████████████▉ | 1476/1500 [22:55<00:22,  1.07it/s]PTBTokenizer tokenized 61766 tokens at 866897.49 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9226 tokens at 224459.67 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  98%|████████████████████████████████████████████████████████████████ | 1477/1500 [22:56<00:21,  1.05it/s]PTBTokenizer tokenized 61766 tokens at 907175.22 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 8482 tokens at 208705.84 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  99%|████████████████████████████████████████████████████████████████ | 1478/1500 [22:57<00:20,  1.05it/s]PTBTokenizer tokenized 61766 tokens at 887223.92 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 999 tokens at 30591.56 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  99%|████████████████████████████████████████████████████████████████ | 1479/1500 [22:58<00:18,  1.12it/s]PTBTokenizer tokenized 61766 tokens at 897705.47 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9694 tokens at 234424.23 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  99%|████████████████████████████████████████████████████████████████▏| 1480/1500 [22:59<00:18,  1.09it/s]PTBTokenizer tokenized 61766 tokens at 905734.87 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9132 tokens at 220241.32 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  99%|████████████████████████████████████████████████████████████████▏| 1481/1500 [23:00<00:17,  1.07it/s]PTBTokenizer tokenized 61766 tokens at 889609.88 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 8110 tokens at 197846.54 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  99%|████████████████████████████████████████████████████████████████▏| 1482/1500 [23:00<00:16,  1.08it/s]PTBTokenizer tokenized 61766 tokens at 856674.22 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 8050 tokens at 201768.71 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  99%|████████████████████████████████████████████████████████████████▎| 1483/1500 [23:01<00:15,  1.07it/s]PTBTokenizer tokenized 61766 tokens at 889511.03 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9412 tokens at 228934.96 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  99%|████████████████████████████████████████████████████████████████▎| 1484/1500 [23:02<00:15,  1.05it/s]PTBTokenizer tokenized 61766 tokens at 883605.60 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9148 tokens at 223973.08 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  99%|████████████████████████████████████████████████████████████████▎| 1485/1500 [23:03<00:14,  1.05it/s]PTBTokenizer tokenized 61766 tokens at 898099.11 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 223162.23 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  99%|████████████████████████████████████████████████████████████████▍| 1486/1500 [23:04<00:13,  1.06it/s]PTBTokenizer tokenized 61766 tokens at 906657.81 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9151 tokens at 208120.48 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  99%|████████████████████████████████████████████████████████████████▍| 1487/1500 [23:05<00:12,  1.04it/s]PTBTokenizer tokenized 61766 tokens at 898821.83 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 7968 tokens at 201776.35 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  99%|████████████████████████████████████████████████████████████████▍| 1488/1500 [23:06<00:11,  1.05it/s]PTBTokenizer tokenized 61766 tokens at 896921.74 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 1999 tokens at 52255.12 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  99%|████████████████████████████████████████████████████████████████▌| 1489/1500 [23:07<00:09,  1.12it/s]PTBTokenizer tokenized 61766 tokens at 892560.67 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 225914.48 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  99%|████████████████████████████████████████████████████████████████▌| 1490/1500 [23:08<00:09,  1.09it/s]PTBTokenizer tokenized 61766 tokens at 909533.45 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 8053 tokens at 199950.58 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  99%|████████████████████████████████████████████████████████████████▌| 1491/1500 [23:09<00:08,  1.07it/s]PTBTokenizer tokenized 61766 tokens at 904450.79 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 226338.80 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files:  99%|████████████████████████████████████████████████████████████████▋| 1492/1500 [23:10<00:07,  1.06it/s]PTBTokenizer tokenized 61766 tokens at 886975.89 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 11791 tokens at 272194.51 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files: 100%|████████████████████████████████████████████████████████████████▋| 1493/1500 [23:11<00:06,  1.04it/s]PTBTokenizer tokenized 61766 tokens at 895651.03 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9251 tokens at 226533.24 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files: 100%|████████████████████████████████████████████████████████████████▋| 1494/1500 [23:12<00:05,  1.05it/s]PTBTokenizer tokenized 61766 tokens at 901309.87 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9254 tokens at 221185.80 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files: 100%|████████████████████████████████████████████████████████████████▊| 1495/1500 [23:13<00:04,  1.04it/s]PTBTokenizer tokenized 61766 tokens at 905514.01 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9239 tokens at 223159.47 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files: 100%|████████████████████████████████████████████████████████████████▊| 1496/1500 [23:14<00:03,  1.04it/s]PTBTokenizer tokenized 61766 tokens at 896402.60 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 8349 tokens at 208207.52 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files: 100%|████████████████████████████████████████████████████████████████▊| 1497/1500 [23:15<00:02,  1.05it/s]PTBTokenizer tokenized 61766 tokens at 898091.53 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 999 tokens at 30592.56 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files: 100%|████████████████████████████████████████████████████████████████▉| 1498/1500 [23:15<00:01,  1.11it/s]PTBTokenizer tokenized 61766 tokens at 894528.66 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9242 tokens at 228394.05 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files: 100%|████████████████████████████████████████████████████████████████▉| 1499/1500 [23:16<00:00,  1.09it/s]PTBTokenizer tokenized 61766 tokens at 855659.23 tokens per second.
# Tokenizing...
# PTBTokenizer tokenized 9169 tokens at 227802.86 tokens per second.
# Computing scores...
# Computing METEOR score...
# Computing CIDEr score...
# Processing files: 100%|█████████████████████████████████████████████████████████████████| 1500/1500 [23:17<00:00,  1.07it/s]
# Results saved to quantization_results.csv

# %%
df = pd.DataFrame(results)

# %%
df
# Out:
#      config  bit_size       type  VIT_FIRST  VIT_MIDDLE  VIT_LAST  \
# 0       894         5        MLP          0           0         0
# 1       678         6  ATTENTION          1           1         1
# 2      1011         5  ATTENTION          1           1         1
# 3      1286         4  ATTENTION          1           1         1
# 4       108        16  ATTENTION          1           1         0
# ...     ...       ...        ...        ...         ...       ...
# 1495    459         8  ATTENTION          0           0         0
# 1496   1212         4  ATTENTION          1           0         0
# 1497   1190         4        MLP          1           1         1
# 1498    874         5        MLP          0           0         0
# 1499    454         8  ATTENTION          1           1         1
#
#       QFORMER_FIRST  QFORMER_MIDDLE  QFORMER_LAST  LLM_FIRST  LLM_MIDDLE  \
# 0                 0               1             1          0           0
# 1                 1               1             1          1           1
# 2                 1               1             1          1           0
# 3                 1               1             1          1           1
# 4                 1               1             1          1           1
# ...             ...             ...           ...        ...         ...
# 1495              1               1             1          0           1
# 1496              1               1             1          1           1
# 1497              0               0             0          0           0
# 1498              1               0             0          0           0
# 1499              0               0             0          1           0
#
#       LLM_LAST    METEOR     CIDEr
# 0            0  0.278521  1.285276
# 1            1  0.266935  1.195565
# 2            1  0.247200  1.073030
# 3            0  0.069629  0.031692
# 4            1  0.278519  1.285213
# ...        ...       ...       ...
# 1495         1  0.278631  1.282046
# 1496         1  0.222587  0.902720
# 1497         1  0.000000  0.000000
# 1498         0  0.278521  1.285276
# 1499         1  0.277867  1.275085
#
# [1500 rows x 14 columns]

# %% [markdown]
# ## Plot Scores and Normalized Scores (Sorted by CIDEr)

# %%
import matplotlib.pyplot as plt

# Assuming you have your data in a DataFrame called 'df'
df_sorted = df.sort_values('CIDEr').reset_index(drop=True)

plt.figure(figsize=(12, 7))

plt.scatter(df_sorted.index, df_sorted['METEOR'], color='blue', alpha=0.5, s=10, label='METEOR')
plt.scatter(df_sorted.index, df_sorted['CIDEr'], color='red', alpha=0.5, s=10, label='CIDEr')

plt.xlabel('Sorted Index', fontsize=12)
plt.ylabel('Score', fontsize=12)
plt.title('METEOR and CIDEr Scores (Sorted by CIDEr)', fontsize=14)
plt.legend(fontsize=10)
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
# Simple min-max normalization function
def normalize(series):
    return (series - series.min()) / (series.max() - series.min())

# Normalize the data
df_normalized = pd.DataFrame({
    'METEOR': normalize(df_sorted['METEOR']),
    'CIDEr': normalize(df_sorted['CIDEr'])
})

plt.figure(figsize=(12, 7))

plt.scatter(df_normalized.index, df_normalized['METEOR'], color='blue', alpha=0.5, s=10, label='METEOR')
plt.scatter(df_normalized.index, df_normalized['CIDEr'], color='red', alpha=0.5, s=10, label='CIDEr')

plt.xlabel('Sorted Index', fontsize=12)
plt.ylabel('Normalized Score', fontsize=12)
plt.title('Normalized METEOR and CIDEr Scores (Sorted by CIDEr)', fontsize=14)
plt.legend(fontsize=10)
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Add Column for Measured Model Size

# %%
import torch
from transformers import Blip2ForConditionalGeneration
from tqdm import tqdm

model = Blip2ForConditionalGeneration.from_pretrained("Salesforce/blip2-opt-2.7b")

def count_parameters(model):
    return sum(p.numel() for p in model.parameters() if p.requires_grad)

# Usage:
total_params = count_parameters(model)
print(f"Total trainable parameters: {total_params}")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Total trainable parameters: 3744679936

# %%
def calculate_quantized_size(model, bit_size, layer_type, vit_first, vit_middle, vit_last, 
                             qformer_first, qformer_middle, qformer_last, 
                             llm_first, llm_middle, llm_last):
    
    def count_layer_params(layer, count_attention, count_mlp):
        param_count = 0
        if count_attention:
            if hasattr(layer, 'self_attn'):
                param_count += sum(p.numel() for p in layer.self_attn.parameters() if p.requires_grad)
            elif hasattr(layer, 'attention'):
                param_count += sum(p.numel() for p in layer.attention.parameters() if p.requires_grad)
        if count_mlp:
            if hasattr(layer, 'mlp'):
                param_count += sum(p.numel() for p in layer.mlp.parameters() if p.requires_grad)
            elif hasattr(layer, 'fc1') and hasattr(layer, 'fc2'):
                param_count += sum(p.numel() for p in layer.fc1.parameters() if p.requires_grad)
                param_count += sum(p.numel() for p in layer.fc2.parameters() if p.requires_grad)
        return param_count

    def quantize_part(layers, first, middle, last):
        total_layers = len(layers)
        first_end = total_layers // 3
        middle_start = first_end
        middle_end = 2 * total_layers // 3
        last_start = middle_end

        quantized_params = 0
        for i, layer in enumerate(layers):
            if (i < first_end and first) or \
               (middle_start <= i < middle_end and middle) or \
               (i >= last_start and last):
                quantized_params += count_layer_params(layer, 
                                                       layer_type in ['BOTH', 'ATTENTION'],
                                                       layer_type in ['BOTH', 'MLP'])
        return quantized_params

    vit_params = quantize_part(model.vision_model.encoder.layers, vit_first, vit_middle, vit_last)
    qformer_params = quantize_part(model.qformer.encoder.layer, qformer_first, qformer_middle, qformer_last)
    llm_params = quantize_part(model.language_model.model.decoder.layers, llm_first, llm_middle, llm_last)

    total_quantized_params = vit_params + qformer_params + llm_params
    total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

    # Calculate the new model size
    original_size = total_params * 32  # Assuming original is 32-bit
    quantized_size = (total_params - total_quantized_params) * 32 + total_quantized_params * bit_size

    return quantized_size

# %% [markdown]
# ## Sanity Checks

# %%
full_size = count_parameters(model) * 32
print(f"Full size: {full_size}")

for layer_type in ['BOTH', 'ATTENTION', 'MLP']:
    print(f"\nTesting with layer_type: {layer_type}")
    
    half_size = calculate_quantized_size(model, 16, layer_type, 1, 1, 1, 1, 1, 1, 1, 1, 1)
    print(f"Calculated half size: {half_size}")
    print(f"Ratio of size between full: {half_size/full_size}")

    quarter = calculate_quantized_size(model, 8, layer_type, 1, 1, 1, 1, 1, 1, 1, 1, 1)
    print(f"Calculated quarter size: {quarter}")
    print(f"Ratio of size between full: {quarter/full_size}")

    eight = calculate_quantized_size(model, 4, layer_type, 1, 1, 1, 1, 1, 1, 1, 1, 1)
    print(f"Calculated eight size: {eight}")
    print(f"Ratio of size between full: {eight/full_size}")
# Out:
# Full size: 119829757952
#
# Testing with layer_type: BOTH
# Calculated half size: 63346178048
# Ratio of size between full: 0.5286347826336633
# Calculated quarter size: 35104388096
# Ratio of size between full: 0.2929521739504949
# Calculated eight size: 20983493120
# Ratio of size between full: 0.17511086960891067
#
# Testing with layer_type: ATTENTION
# Calculated half size: 100997128192
# Ratio of size between full: 0.8428384561408881
# Calculated quarter size: 91580813312
# Ratio of size between full: 0.7642576842113323
# Calculated eight size: 86872655872
# Ratio of size between full: 0.7249672982465544
#
# Testing with layer_type: MLP
# Calculated half size: 82178807808
# Ratio of size between full: 0.6857963264927751
# Calculated quarter size: 63353332736
# Ratio of size between full: 0.5286944897391626
# Calculated eight size: 53940595200
# Ratio of size between full: 0.45014357136235633

# %%
def apply_quantization(row, model):
    return calculate_quantized_size(
        model,
        row['bit_size'],
        row['type'],
        row['VIT_FIRST'],
        row['VIT_MIDDLE'],
        row['VIT_LAST'],
        row['QFORMER_FIRST'],
        row['QFORMER_MIDDLE'],
        row['QFORMER_LAST'],
        row['LLM_FIRST'],
        row['LLM_MIDDLE'],
        row['LLM_LAST']
    )

# Assuming your DataFrame is called 'df' and your model is called 'model'
df['quantized_size'] = df.apply(lambda row: apply_quantization(row, model), axis=1)

# Calculate the compression ratio
total_params = count_parameters(model)
original_size = total_params * 32
df['compression_ratio'] = df['quantized_size'] / original_size

# %%
df
# Out:
#      config  bit_size       type  VIT_FIRST  VIT_MIDDLE  VIT_LAST  \
# 0       894         5        MLP          0           0         0
# 1       678         6  ATTENTION          1           1         1
# 2      1011         5  ATTENTION          1           1         1
# 3      1286         4  ATTENTION          1           1         1
# 4       108        16  ATTENTION          1           1         0
# ...     ...       ...        ...        ...         ...       ...
# 1495    459         8  ATTENTION          0           0         0
# 1496   1212         4  ATTENTION          1           0         0
# 1497   1190         4        MLP          1           1         1
# 1498    874         5        MLP          0           0         0
# 1499    454         8  ATTENTION          1           1         1
#
#       QFORMER_FIRST  QFORMER_MIDDLE  QFORMER_LAST  LLM_FIRST  LLM_MIDDLE  \
# 0                 0               1             1          0           0
# 1                 1               1             1          1           1
# 2                 1               1             1          1           0
# 3                 1               1             1          1           1
# 4                 1               1             1          1           1
# ...             ...             ...           ...        ...         ...
# 1495              1               1             1          0           1
# 1496              1               1             1          1           1
# 1497              0               0             0          0           0
# 1498              1               0             0          0           0
# 1499              0               0             0          1           0
#
#       LLM_LAST    METEOR     CIDEr  quantized_size  compression_ratio
# 0            0  0.278521  1.285276    119829757952           1.000000
# 1            1  0.266935  1.195565     89226734592           0.744612
# 2            1  0.247200  1.073030     95838413312           0.799788
# 3            0  0.069629  0.031692     94949844992           0.792373
# 4            1  0.278519  1.285213    102647709696           0.856613
# ...        ...       ...       ...             ...                ...
# 1495         1  0.278631  1.282046    105302343680           0.878766
# 1496         1  0.222587  0.902720     92649691136           0.773178
# 1497         1  0.000000  0.000000     84776256000           0.707472
# 1498         0  0.278521  1.285276    119829757952           1.000000
# 1499         1  0.277867  1.275085     99184922624           0.827715
#
# [1500 rows x 16 columns]

# %%
import plotly.graph_objects as go

hover_text = df.apply(lambda row: '<br>'.join([
    f"{col}: {row[col]}" for col in df.columns
]), axis=1)

fig = go.Figure(data=[go.Scatter3d(
    x=df['METEOR'],
    y=df['CIDEr'],
    z=df['quantized_size'],
    mode='markers',
    marker=dict(
        size=5,
        color=df['compression_ratio'],
        colorscale='Viridis',
        opacity=0.8,
        colorbar=dict(title='Compression Ratio')
    ),
    text=hover_text,
    hoverinfo='text'
)])

fig.update_layout(
    title='3D Scatter Plot of METEOR, CIDEr, and Quantized Size',
    scene=dict(
        xaxis_title='METEOR',
        yaxis_title='CIDEr',
        zaxis_title='Quantized Size'
    ),
    width=800,
    height=800,
    margin=dict(r=20, b=10, l=10, t=40)
)

fig.write_html("3d_plot.html")

# %% [markdown]
# ## QFormer Bug

# %%
df[df["compression_ratio"]>=1]
# Out:
#      config  bit_size type  VIT_FIRST  VIT_MIDDLE  VIT_LAST  QFORMER_FIRST  \
# 0       894         5  MLP          0           0         0              0
# 54     1452         3  MLP          0           0         0              0
# 93      882         5  MLP          0           0         0              0
# 133     316         8  MLP          0           0         0              1
# 153      61        16  MLP          0           0         0              1
# 182     280         8  MLP          0           0         0              1
# 183      64        16  MLP          0           0         0              1
# 229     599         6  MLP          0           0         0              0
# 310     340         8  MLP          0           0         0              1
# 337    1177         4  MLP          0           0         0              1
# 341     615         6  MLP          0           0         0              0
# 398     898         5  MLP          0           0         0              1
# 402     320         8  MLP          0           0         0              0
# 411    1444         3  MLP          0           0         0              1
# 476     619         6  MLP          0           0         0              1
# 481     332         8  MLP          0           0         0              1
# 514       1        16  MLP          0           0         0              1
# 571     622         6  MLP          0           0         0              1
# 628    1396         3  MLP          0           0         0              1
# 635    1169         4  MLP          0           0         0              1
# 683    1180         4  MLP          0           0         0              1
# 719     607         6  MLP          0           0         0              1
# 724     343         8  MLP          0           0         0              1
# 746      41        16  MLP          0           0         0              0
# 752     901         5  MLP          0           0         0              1
# 815     324         8  MLP          0           0         0              0
# 818     890         5  MLP          0           0         0              1
# 820     603         6  MLP          0           0         0              0
# 826     559         6  MLP          0           0         0              1
# 835    1161         4  MLP          0           0         0              0
# 878    1440         3  MLP          0           0         0              0
# 909      49        16  MLP          0           0         0              1
# 937     878         5  MLP          0           0         0              0
# 953    1448         3  MLP          0           0         0              1
# 989     838         5  MLP          0           0         0              1
# 1033     37        16  MLP          0           0         0              1
# 1057   1173         4  MLP          0           0         0              0
# 1080    611         6  MLP          0           0         0              1
# 1193    595         6  MLP          0           0         0              1
# 1210   1459         3  MLP          0           0         0              1
# 1212   1165         4  MLP          0           0         0              1
# 1213   1117         4  MLP          0           0         0              1
# 1219     57        16  MLP          0           0         0              0
# 1222   1153         4  MLP          0           0         0              1
# 1247    328         8  MLP          0           0         0              1
# 1253    886         5  MLP          0           0         0              1
# 1258   1456         3  MLP          0           0         0              1
# 1276     53        16  MLP          0           0         0              1
# 1321     45        16  MLP          0           0         0              0
# 1389    336         8  MLP          0           0         0              0
# 1417   1436         3  MLP          0           0         0              0
# 1420   1432         3  MLP          0           0         0              1
# 1423   1157         4  MLP          0           0         0              0
# 1498    874         5  MLP          0           0         0              1
#
#       QFORMER_MIDDLE  QFORMER_LAST  LLM_FIRST  LLM_MIDDLE  LLM_LAST    METEOR  \
# 0                  1             1          0           0         0  0.278521
# 54                 1             1          0           0         0  0.278521
# 93                 0             1          0           0         0  0.278521
# 133                0             0          0           0         0  0.278521
# 153                1             1          0           0         0  0.278521
# 182                1             1          0           0         0  0.278521
# 183                1             1          0           0         0  0.278521
# 229                1             0          0           0         0  0.278521
# 310                1             1          0           0         0  0.278521
# 337                1             1          0           0         0  0.278521
# 341                1             1          0           0         0  0.278521
# 398                1             1          0           0         0  0.278521
# 402                1             0          0           0         0  0.278521
# 411                1             0          0           0         0  0.278521
# 476                1             1          0           0         0  0.278521
# 481                0             1          0           0         0  0.278521
# 514                1             1          0           0         0  0.278521
# 571                1             1          0           0         0  0.278521
# 628                1             1          0           0         0  0.278521
# 635                0             1          0           0         0  0.278521
# 683                1             1          0           0         0  0.278521
# 719                1             0          0           0         0  0.278521
# 724                1             1          0           0         0  0.278521
# 746                1             0          0           0         0  0.278521
# 752                1             1          0           0         0  0.278521
# 815                0             1          0           0         0  0.278521
# 818                0             1          0           0         0  0.278521
# 820                0             1          0           0         0  0.278521
# 826                1             1          0           0         0  0.278521
# 835                0             1          0           0         0  0.278521
# 878                0             1          0           0         0  0.278521
# 909                1             0          0           0         0  0.278521
# 937                1             0          0           0         0  0.278521
# 953                0             1          0           0         0  0.278521
# 989                1             1          0           0         0  0.278521
# 1033               0             0          0           0         0  0.278521
# 1057               1             1          0           0         0  0.278521
# 1080               0             1          0           0         0  0.278521
# 1193               0             0          0           0         0  0.278521
# 1210               1             1          0           0         0  0.278521
# 1212               1             0          0           0         0  0.278521
# 1213               1             1          0           0         0  0.278521
# 1219               1             1          0           0         0  0.278521
# 1222               0             0          0           0         0  0.278521
# 1247               1             0          0           0         0  0.278521
# 1253               1             0          0           0         0  0.278521
# 1258               1             1          0           0         0  0.278521
# 1276               0             1          0           0         0  0.278521
# 1321               0             1          0           0         0  0.278521
# 1389               1             1          0           0         0  0.278521
# 1417               1             0          0           0         0  0.278521
# 1420               0             0          0           0         0  0.278521
# 1423               1             0          0           0         0  0.278521
# 1498               0             0          0           0         0  0.278521
#
#          CIDEr  quantized_size  compression_ratio
# 0     1.285276    119829757952                1.0
# 54    1.285276    119829757952                1.0
# 93    1.285276    119829757952                1.0
# 133   1.285276    119829757952                1.0
# 153   1.285276    119829757952                1.0
# 182   1.285276    119829757952                1.0
# 183   1.285276    119829757952                1.0
# 229   1.285276    119829757952                1.0
# 310   1.285276    119829757952                1.0
# 337   1.285276    119829757952                1.0
# 341   1.285276    119829757952                1.0
# 398   1.285276    119829757952                1.0
# 402   1.285276    119829757952                1.0
# 411   1.285276    119829757952                1.0
# 476   1.285276    119829757952                1.0
# 481   1.285276    119829757952                1.0
# 514   1.285276    119829757952                1.0
# 571   1.285276    119829757952                1.0
# 628   1.285276    119829757952                1.0
# 635   1.285276    119829757952                1.0
# 683   1.285276    119829757952                1.0
# 719   1.285276    119829757952                1.0
# 724   1.285276    119829757952                1.0
# 746   1.285276    119829757952                1.0
# 752   1.285276    119829757952                1.0
# 815   1.285276    119829757952                1.0
# 818   1.285276    119829757952                1.0
# 820   1.285276    119829757952                1.0
# 826   1.285276    119829757952                1.0
# 835   1.285276    119829757952                1.0
# 878   1.285276    119829757952                1.0
# 909   1.285276    119829757952                1.0
# 937   1.285276    119829757952                1.0
# 953   1.285276    119829757952                1.0
# 989   1.285276    119829757952                1.0
# 1033  1.285276    119829757952                1.0
# 1057  1.285276    119829757952                1.0
# 1080  1.285276    119829757952                1.0
# 1193  1.285276    119829757952                1.0
# 1210  1.285276    119829757952                1.0
# 1212  1.285276    119829757952                1.0
# 1213  1.285276    119829757952                1.0
# 1219  1.285276    119829757952                1.0
# 1222  1.285276    119829757952                1.0
# 1247  1.285276    119829757952                1.0
# 1253  1.285276    119829757952                1.0
# 1258  1.285276    119829757952                1.0
# 1276  1.285276    119829757952                1.0
# 1321  1.285276    119829757952                1.0
# 1389  1.285276    119829757952                1.0
# 1417  1.285276    119829757952                1.0
# 1420  1.285276    119829757952                1.0
# 1423  1.285276    119829757952                1.0
# 1498  1.285276    119829757952                1.0

# %%
def calculate_quantized_size(model, bit_size, layer_type, vit_first, vit_middle, vit_last, 
                             qformer_first, qformer_middle, qformer_last, 
                             llm_first, llm_middle, llm_last):
    
    def count_layer_params(layer, count_attention, count_mlp):
        param_count = 0
        if count_attention:
            if hasattr(layer, 'self_attn'):
                param_count += sum(p.numel() for p in layer.self_attn.parameters() if p.requires_grad)
            elif hasattr(layer, 'attention'):
                param_count += sum(p.numel() for p in layer.attention.parameters() if p.requires_grad)
        if count_mlp:
            if hasattr(layer, 'mlp'):
                param_count += sum(p.numel() for p in layer.mlp.parameters() if p.requires_grad)
            elif hasattr(layer, 'fc1') and hasattr(layer, 'fc2'):
                param_count += sum(p.numel() for p in layer.fc1.parameters() if p.requires_grad)
                param_count += sum(p.numel() for p in layer.fc2.parameters() if p.requires_grad)
        return param_count

    def quantize_part(layers, first, middle, last):
        total_layers = len(layers)
        first_end = total_layers // 3
        middle_start = first_end
        middle_end = 2 * total_layers // 3
        last_start = middle_end

        quantized_params = 0
        for i, layer in enumerate(layers):
            if (i < first_end and first) or \
               (middle_start <= i < middle_end and middle) or \
               (i >= last_start and last):
                quantized_params += count_layer_params(layer, 
                                                       layer_type in ['BOTH', 'ATTENTION'],
                                                       layer_type in ['BOTH', 'MLP'])
        return quantized_params

    vit_params = quantize_part(model.vision_model.encoder.layers, vit_first, vit_middle, vit_last)
    qformer_params = quantize_part(model.qformer.encoder.layer, qformer_first, qformer_middle, qformer_last)
    llm_params = quantize_part(model.language_model.model.decoder.layers, llm_first, llm_middle, llm_last)

    print(f"VIT params quantized: {vit_params}")
    print(f"QFormer params quantized: {qformer_params}")
    print(f"LLM params quantized: {llm_params}")

    total_quantized_params = vit_params + qformer_params + llm_params
    total_params = sum(p.numel() for p in model.parameters() if p.requires_grad)

    print(f"Total params: {total_params}")
    print(f"Total quantized params: {total_quantized_params}")

    # Calculate the new model size
    original_size = total_params * 32  # Assuming original is 32-bit
    quantized_size = (total_params - total_quantized_params) * 32 + total_quantized_params * bit_size

    return quantized_size

# %%
import torch
from torch import nn

# Assuming you have your BLIP-2 model loaded as 'model'

def test_qformer_structure():
    print("QFormer Structure:")
    print(model.qformer)
    print("\nNumber of QFormer layers:", len(model.qformer.encoder.layer))

def count_qformer_params():
    return sum(p.numel() for p in model.qformer.parameters() if p.requires_grad)

def test_qformer_param_count():
    qformer_params = count_qformer_params()
    print(f"Total QFormer parameters: {qformer_params}")

def test_qformer_layer_param_count():
    for i, layer in enumerate(model.qformer.encoder.layer):
        layer_params = sum(p.numel() for p in layer.parameters() if p.requires_grad)
        print(f"QFormer Layer {i} parameters: {layer_params}")

def test_qformer_quantization(bit_size, layer_type, first, middle, last):
    def count_layer_params(layer, count_attention, count_mlp):
        param_count = 0
        if count_attention:
            if hasattr(layer, 'self_attn'):
                param_count += sum(p.numel() for p in layer.self_attn.parameters() if p.requires_grad)
            elif hasattr(layer, 'attention'):
                param_count += sum(p.numel() for p in layer.attention.parameters() if p.requires_grad)
        if count_mlp:
            if hasattr(layer, 'mlp'):
                param_count += sum(p.numel() for p in layer.mlp.parameters() if p.requires_grad)
            elif hasattr(layer, 'fc1') and hasattr(layer, 'fc2'):
                param_count += sum(p.numel() for p in layer.fc1.parameters() if p.requires_grad)
                param_count += sum(p.numel() for p in layer.fc2.parameters() if p.requires_grad)
        return param_count

    layers = model.qformer.encoder.layer
    total_layers = len(layers)
    first_end = total_layers // 3
    middle_start = first_end
    middle_end = 2 * total_layers // 3
    last_start = middle_end

    quantized_params = 0
    for i, layer in enumerate(layers):
        if (i < first_end and first) or \
           (middle_start <= i < middle_end and middle) or \
           (i >= last_start and last):
            layer_params = count_layer_params(layer, 
                                              layer_type in ['BOTH', 'ATTENTION'],
                                              layer_type in ['BOTH', 'MLP'])
            quantized_params += layer_params
            print(f"Layer {i} quantized parameters: {layer_params}")

    print(f"Total QFormer quantized parameters: {quantized_params}")
    total_params = count_qformer_params()
    print(f"QFormer compression ratio: {quantized_params * bit_size / (total_params * 32):.4f}")

# Run the tests
print("Test 1: QFormer Structure")
test_qformer_structure()

print("\nTest 2: QFormer Parameter Count")
test_qformer_param_count()

print("\nTest 3: QFormer Layer-wise Parameter Count")
test_qformer_layer_param_count()

print("\nTest 4: QFormer Quantization (8-bit, MLP, all layers)")
test_qformer_quantization(8, 'MLP', True, True, True)

print("\nTest 5: QFormer Quantization (4-bit, ATTENTION, first third)")
test_qformer_quantization(4, 'ATTENTION', True, False, False)

print("\nTest 6: QFormer Quantization (16-bit, BOTH, middle third)")
test_qformer_quantization(16, 'BOTH', False, True, False)
# Out:
# Test 1: QFormer Structure
# QFormer Structure:
# Blip2QFormerModel(
#   (layernorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#   (dropout): Dropout(p=0.1, inplace=False)
#   (encoder): Blip2QFormerEncoder(
#     (layer): ModuleList(
#       (0): Blip2QFormerLayer(
#         (attention): Blip2QFormerAttention(
#           (attention): Blip2QFormerMultiHeadAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): Blip2QFormerSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (crossattention): Blip2QFormerAttention(
#           (attention): Blip2QFormerMultiHeadAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=1408, out_features=768, bias=True)
#             (value): Linear(in_features=1408, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): Blip2QFormerSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate_query): Blip2QFormerIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output_query): Blip2QFormerOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (1): Blip2QFormerLayer(
#         (attention): Blip2QFormerAttention(
#           (attention): Blip2QFormerMultiHeadAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): Blip2QFormerSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate_query): Blip2QFormerIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output_query): Blip2QFormerOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (2): Blip2QFormerLayer(
#         (attention): Blip2QFormerAttention(
#           (attention): Blip2QFormerMultiHeadAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): Blip2QFormerSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (crossattention): Blip2QFormerAttention(
#           (attention): Blip2QFormerMultiHeadAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=1408, out_features=768, bias=True)
#             (value): Linear(in_features=1408, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): Blip2QFormerSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate_query): Blip2QFormerIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output_query): Blip2QFormerOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (3): Blip2QFormerLayer(
#         (attention): Blip2QFormerAttention(
#           (attention): Blip2QFormerMultiHeadAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): Blip2QFormerSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate_query): Blip2QFormerIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output_query): Blip2QFormerOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (4): Blip2QFormerLayer(
#         (attention): Blip2QFormerAttention(
#           (attention): Blip2QFormerMultiHeadAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): Blip2QFormerSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (crossattention): Blip2QFormerAttention(
#           (attention): Blip2QFormerMultiHeadAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=1408, out_features=768, bias=True)
#             (value): Linear(in_features=1408, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): Blip2QFormerSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate_query): Blip2QFormerIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output_query): Blip2QFormerOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (5): Blip2QFormerLayer(
#         (attention): Blip2QFormerAttention(
#           (attention): Blip2QFormerMultiHeadAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): Blip2QFormerSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate_query): Blip2QFormerIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output_query): Blip2QFormerOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (6): Blip2QFormerLayer(
#         (attention): Blip2QFormerAttention(
#           (attention): Blip2QFormerMultiHeadAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): Blip2QFormerSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (crossattention): Blip2QFormerAttention(
#           (attention): Blip2QFormerMultiHeadAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=1408, out_features=768, bias=True)
#             (value): Linear(in_features=1408, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): Blip2QFormerSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate_query): Blip2QFormerIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output_query): Blip2QFormerOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (7): Blip2QFormerLayer(
#         (attention): Blip2QFormerAttention(
#           (attention): Blip2QFormerMultiHeadAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): Blip2QFormerSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate_query): Blip2QFormerIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output_query): Blip2QFormerOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (8): Blip2QFormerLayer(
#         (attention): Blip2QFormerAttention(
#           (attention): Blip2QFormerMultiHeadAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): Blip2QFormerSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (crossattention): Blip2QFormerAttention(
#           (attention): Blip2QFormerMultiHeadAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=1408, out_features=768, bias=True)
#             (value): Linear(in_features=1408, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): Blip2QFormerSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate_query): Blip2QFormerIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output_query): Blip2QFormerOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (9): Blip2QFormerLayer(
#         (attention): Blip2QFormerAttention(
#           (attention): Blip2QFormerMultiHeadAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): Blip2QFormerSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate_query): Blip2QFormerIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output_query): Blip2QFormerOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (10): Blip2QFormerLayer(
#         (attention): Blip2QFormerAttention(
#           (attention): Blip2QFormerMultiHeadAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): Blip2QFormerSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (crossattention): Blip2QFormerAttention(
#           (attention): Blip2QFormerMultiHeadAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=1408, out_features=768, bias=True)
#             (value): Linear(in_features=1408, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): Blip2QFormerSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate_query): Blip2QFormerIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output_query): Blip2QFormerOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#       (11): Blip2QFormerLayer(
#         (attention): Blip2QFormerAttention(
#           (attention): Blip2QFormerMultiHeadAttention(
#             (query): Linear(in_features=768, out_features=768, bias=True)
#             (key): Linear(in_features=768, out_features=768, bias=True)
#             (value): Linear(in_features=768, out_features=768, bias=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (output): Blip2QFormerSelfOutput(
#             (dense): Linear(in_features=768, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (intermediate_query): Blip2QFormerIntermediate(
#           (dense): Linear(in_features=768, out_features=3072, bias=True)
#           (intermediate_act_fn): GELUActivation()
#         )
#         (output_query): Blip2QFormerOutput(
#           (dense): Linear(in_features=3072, out_features=768, bias=True)
#           (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#           (dropout): Dropout(p=0.1, inplace=False)
#         )
#       )
#     )
#   )
# )
#
# Number of QFormer layers: 12
#
# Test 2: QFormer Parameter Count
# Total QFormer parameters: 105137664
#
# Test 3: QFormer Layer-wise Parameter Count
# QFormer Layer 0 parameters: 10434816
# QFormer Layer 1 parameters: 7087872
# QFormer Layer 2 parameters: 10434816
# QFormer Layer 3 parameters: 7087872
# QFormer Layer 4 parameters: 10434816
# QFormer Layer 5 parameters: 7087872
# QFormer Layer 6 parameters: 10434816
# QFormer Layer 7 parameters: 7087872
# QFormer Layer 8 parameters: 10434816
# QFormer Layer 9 parameters: 7087872
# QFormer Layer 10 parameters: 10434816
# QFormer Layer 11 parameters: 7087872
#
# Test 4: QFormer Quantization (8-bit, MLP, all layers)
# Layer 0 quantized parameters: 0
# Layer 1 quantized parameters: 0
# Layer 2 quantized parameters: 0
# Layer 3 quantized parameters: 0
# Layer 4 quantized parameters: 0
# Layer 5 quantized parameters: 0
# Layer 6 quantized parameters: 0
# Layer 7 quantized parameters: 0
# Layer 8 quantized parameters: 0
# Layer 9 quantized parameters: 0
# Layer 10 quantized parameters: 0
# Layer 11 quantized parameters: 0
# Total QFormer quantized parameters: 0
# QFormer compression ratio: 0.0000
#
# Test 5: QFormer Quantization (4-bit, ATTENTION, first third)
# Layer 0 quantized parameters: 2363904
# Layer 1 quantized parameters: 2363904
# Layer 2 quantized parameters: 2363904
# Layer 3 quantized parameters: 2363904
# Total QFormer quantized parameters: 9455616
# QFormer compression ratio: 0.0112
#
# Test 6: QFormer Quantization (16-bit, BOTH, middle third)
# Layer 4 quantized parameters: 2363904
# Layer 5 quantized parameters: 2363904
# Layer 6 quantized parameters: 2363904
# Layer 7 quantized parameters: 2363904
# Total QFormer quantized parameters: 9455616
# QFormer compression ratio: 0.0450

# %%
def count_mlp_layers(model, model_name):
    mlp_count = 0
    for name, module in model.named_modules():
        if 'mlp' in name.lower() or 'mlp' in name.lower() or ('intermediate' in name.lower() and 'dense' in name.lower()):
            mlp_count += 1
    print(f"Number of MLP layers in {model_name}: {mlp_count}")

# Count MLP layers in the vision model
count_mlp_layers(model.vision_model, "Vision Model")

# Count MLP layers in the language model
count_mlp_layers(model.language_model, "Language Model")
# Out:
# Number of MLP layers in Vision Model: 156
# Number of MLP layers in Language Model: 0

# %%
def count_mlp_layers(model, model_name):
    mlp_count = 0
    for name, module in model.named_modules():
        if 'fc1' in name.lower() or 'fc1' in name.lower() or ('intermediate' in name.lower() and 'dense' in name.lower()):
            mlp_count += 1
        elif 'fc2' in name.lower() or 'fc2' in name.lower() or ('intermediate' in name.lower() and 'dense' in name.lower()):
            mlp_count += 1
    print(f"Number of FC1 layers in {model_name}: {mlp_count}")

# Count MLP layers in the vision model
count_mlp_layers(model.vision_model, "Vision Model")

# Count MLP layers in the language model
count_mlp_layers(model.language_model, "Language Model")
# Out:
# Number of FC1 layers in Vision Model: 78
# Number of FC1 layers in Language Model: 64

# %%
model.language_model
# Out:
# OPTForCausalLM(
#   (model): OPTModel(
#     (decoder): OPTDecoder(
#       (embed_tokens): Embedding(50272, 2560, padding_idx=1)
#       (embed_positions): OPTLearnedPositionalEmbedding(2050, 2560)
#       (final_layer_norm): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#       (layers): ModuleList(
#         (0-31): 32 x OPTDecoderLayer(
#           (self_attn): OPTAttention(
#             (k_proj): Linear(in_features=2560, out_features=2560, bias=True)
#             (v_proj): Linear(in_features=2560, out_features=2560, bias=True)
#             (q_proj): Linear(in_features=2560, out_features=2560, bias=True)
#             (out_proj): Linear(in_features=2560, out_features=2560, bias=True)
#           )
#           (activation_fn): ReLU()
#           (self_attn_layer_norm): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#           (fc1): Linear(in_features=2560, out_features=10240, bias=True)
#           (fc2): Linear(in_features=10240, out_features=2560, bias=True)
#           (final_layer_norm): LayerNorm((2560,), eps=1e-05, elementwise_affine=True)
#         )
#       )
#     )
#   )
#   (lm_head): Linear(in_features=2560, out_features=50272, bias=False)
# )

# %%
model.vision_model
# Out:
# Blip2VisionModel(
#   (embeddings): Blip2VisionEmbeddings(
#     (patch_embedding): Conv2d(3, 1408, kernel_size=(14, 14), stride=(14, 14))
#   )
#   (encoder): Blip2Encoder(
#     (layers): ModuleList(
#       (0-38): 39 x Blip2EncoderLayer(
#         (self_attn): Blip2Attention(
#           (dropout): Dropout(p=0.0, inplace=False)
#           (qkv): Linear(in_features=1408, out_features=4224, bias=True)
#           (projection): Linear(in_features=1408, out_features=1408, bias=True)
#         )
#         (layer_norm1): LayerNorm((1408,), eps=1e-06, elementwise_affine=True)
#         (mlp): Blip2MLP(
#           (activation_fn): GELUActivation()
#           (fc1): Linear(in_features=1408, out_features=6144, bias=True)
#           (fc2): Linear(in_features=6144, out_features=1408, bias=True)
#         )
#         (layer_norm2): LayerNorm((1408,), eps=1e-06, elementwise_affine=True)
#       )
#     )
#   )
#   (post_layernorm): LayerNorm((1408,), eps=1e-06, elementwise_affine=True)
# )
